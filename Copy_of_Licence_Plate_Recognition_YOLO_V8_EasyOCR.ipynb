# %% [markdown]
# <a href="https://colab.research.google.com/github/Niveditha-lab/OCR/blob/main/Copy_of_Licence_Plate_Recognition_YOLO_V8_EasyOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Arijit1080/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR.git
# Out:
# Cloning into 'Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 135 (delta 0), reused 0 (delta 0), pack-reused 134 (from 2)
# Receiving objects: 100% (135/135), 14.74 MiB | 20.96 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
cd /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR
# Out:
# /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR

# %%
pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.5/247.5 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 48.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 kB 24.9 MB/s eta 0:00:00
# ...

# %%
# !python predictWithOCR.py model='/content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/best.pt' source='/content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/demo.mp4'
# Out:
# 2023-09-09 22:08:52.652688: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 22:08:53.665478: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# video 1/1 (1/631) /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/demo.mp4: 416x640 1 LicensePlate, 68.1ms
# video 1/1 (2/631) /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/demo.mp4: 416x640 1 LicensePlate, 6.2ms
# ...
